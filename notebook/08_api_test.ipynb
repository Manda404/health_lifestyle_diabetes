# %% [markdown]
# ### 🧠 End-to-End Training Pipeline (Feature Engineering, Feature Selection & CatBoost)

# %%
# ============================================================
# 0. Imports
# ============================================================
from pathlib import Path
from catboost import CatBoostClassifier

from health_lifestyle_diabetes.infrastructure.logger.config import configure_logging
from health_lifestyle_diabetes.infrastructure.logger.loguru_logger import LoguruLogger

from health_lifestyle_diabetes.infrastructure.utils.config_loader import YamlConfigLoader
from health_lifestyle_diabetes.infrastructure.utils.paths import get_repository_root

from health_lifestyle_diabetes.infrastructure.data_sources.csv_dataset_repository import (
    CSVDatasetRepository
)
from health_lifestyle_diabetes.infrastructure.feature_engineering.pipeline_feature_engineering import (
    FeatureEngineeringPipeline
)
from health_lifestyle_diabetes.infrastructure.splitters.sklearn_splitter import (
    SklearnDatasetSplitter
)
from health_lifestyle_diabetes.infrastructure.model_trainers.catboost_trainer import (
    CatBoostTrainer
)
from health_lifestyle_diabetes.infrastructure.features_selections import (
    features_selection as fs
)

# ============================================================
# 1. Configuration & logging
# ============================================================
configure_logging(env="dev")
logger = LoguruLogger()

root = get_repository_root()
config_loader = YamlConfigLoader()

paths_cfg = config_loader.load_config(root / "configs/paths.yaml")
splitter_cfg = config_loader.load_config(root / "configs/splitter.yaml")

# ============================================================
# 2. Chargement des données
# ============================================================
train_data_path = root / Path(paths_cfg["data"]["input"]["train_dataset"])

dataset_repo = CSVDatasetRepository(
    source_path=train_data_path,
    logger=logger,
)

raw_df = dataset_repo.load_dataset()

logger.info(
    f"Dataset chargé | "
    f"lignes={raw_df.shape[0]} | "
    f"colonnes={raw_df.shape[1]}"
)

# ============================================================
# 3. Feature Engineering
# ============================================================
fe_pipeline = FeatureEngineeringPipeline(logger=logger)
enriched_df = fe_pipeline.transform(raw_df)

logger.info(
    "Feature engineering terminé | "
    f"colonnes_avant={raw_df.shape[1]} | "
    f"colonnes_après={enriched_df.shape[1]}"
)

# ============================================================
# 4. Split Train / Validation
# ============================================================
splitter = SklearnDatasetSplitter(
    train_size=splitter_cfg["splitter"]["train_size"],
    target_column=fs.TARGET_COLUMN,
    random_state=splitter_cfg["splitter"]["random_state"],
    logger=logger,
)

train_df, valid_df = splitter.split(enriched_df)

logger.info(f"Train shape : {train_df.shape}")
logger.info(f"Valid shape : {valid_df.shape}")

# ============================================================
# 4.b Feature Selection (IMPORTANT)
# ============================================================
logger.info(
    f"Feature selection | "
    f"{len(fs.SELECTED_FEATURES)} features retenues"
)

# On garde uniquement les features utiles + la cible
train_df = train_df[fs.SELECTED_FEATURES + [fs.TARGET_COLUMN]]
valid_df = valid_df[fs.SELECTED_FEATURES + [fs.TARGET_COLUMN]]

logger.info("Feature selection appliquée")

# ============================================================
# 5. Préparation X / y
# ============================================================
X_train = train_df.drop(columns=[fs.TARGET_COLUMN])
y_train = train_df[fs.TARGET_COLUMN]

X_valid = valid_df.drop(columns=[fs.TARGET_COLUMN])
y_valid = valid_df[fs.TARGET_COLUMN]

logger.info(
    "Dimensions finales | "
    f"X_train={X_train.shape} | "
    f"X_valid={X_valid.shape}"
)

# ============================================================
# 6. Entraînement CatBoost
# ============================================================
catboost_params = {
    "iterations": 500,
    "learning_rate": 0.5,
    "depth": 6,
    "loss_function": "Logloss",
    "eval_metric": "Logloss",
    "verbose": 100,
}

trainer = CatBoostTrainer(
    params=catboost_params,
    logger=logger,
)

model = trainer.train(
    X_train=X_train,
    y_train=y_train,
    X_valid=X_valid,
    y_valid=y_valid,
)

logger.info("Entraînement CatBoost terminé")

# ============================================================
# 7. Sauvegarde du modèle (overwrite)
# ============================================================
MODEL_PATH = (
    root
    / "models"
    / "catboost_diabetes_classifier.cbm"
)
MODEL_PATH.parent.mkdir(parents=True, exist_ok=True)

model.save_model(MODEL_PATH)
logger.info(f"Modèle sauvegardé : {MODEL_PATH}")

# ============================================================
# 8. Chargement du modèle (sanity check)
# ============================================================
#loaded_model = CatBoostClassifier()
#loaded_model.load_model(MODEL_PATH)

#logger.info("Modèle rechargé avec succès")
# Out:
# 2026-01-03 18:01:33 | INFO     | config.py:67 | configure_logging() | Loguru configuré avec succès (mode: dev) | {'env': 'dev'}
# 2026-01-03 18:01:33 | INFO     | csv_dataset_repository.py:54 | load_dataset() | Chargement du dataset depuis : /Users/surelmanda/Downloads/ml-projects/Clean-Architecture-MLops/health_lifestyle_diabetes/data/input/train.csv | {}
# 2026-01-03 18:01:34 | INFO     | csv_dataset_repository.py:61 | load_dataset() | Dataset chargé avec succès (82702 lignes, 31 colonnes). | {}
# 2026-01-03 18:01:34 | INFO     | 1594397751.py:53 | <module>() | Dataset chargé | lignes=82702 | colonnes=31 | {}
# 2026-01-03 18:01:34 | INFO     | pipeline_feature_engineering.py:82 | transform() | Démarrage du pipeline complet de Feature Engineering... | {}
# 2026-01-03 18:01:34 | INFO     | exclusion.py:36 | drop_leakage_columns() | Vérification des colonnes à risque de data leakage... | {}
# 2026-01-03 18:01:34 | INFO     | exclusion.py:40 | drop_leakage_columns() | Suppression des colonnes à risque de leakage : ['diabetes_risk_score', 'diabetes_stage'] | {}
# 2026-01-03 18:01:34 | INFO     | base_preprocessing.py:25 | clean_categorical_variables() | Nettoyage des variables catégorielles... | {}
# 2026-01-03 18:01:34 | INFO     | base_preprocessing.py:32 | clean_categorical_variables() | Libellés uniformisés avec succès. | {}
# 2026-01-03 18:01:34 | INFO     | demographics_features.py:82 | transform() | Création des variables démographiques... | {}
# 2026-01-03 18:01:34 | INFO     | demographics_features.py:68 | _create_age_group() | Utilisation du découpage d'âge en 3 catégories. | {}
# 2026-01-03 18:01:34 | INFO     | demographics_features.py:111 | transform() | Variables démographiques complétées. | {}
# 2026-01-03 18:01:34 | INFO     | medical_features.py:86 | transform() | Application des transformations médicales... | {}
# 2026-01-03 18:01:34 | INFO     | medical_features.py:94 | transform() | Transformations médicales complétées. | {}
# 2026-01-03 18:01:34 | INFO     | clinical_features.py:32 | transform() | Calcul des ratios et interactions cliniques... | {}
# 2026-01-03 18:01:34 | INFO     | clinical_features.py:41 | transform() | Variables cliniques ajoutées avec succès. | {}
# 2026-01-03 18:01:34 | INFO     | metabolic_features.py:41 | transform() | Création des features métaboliques avancées... | {}
# 2026-01-03 18:01:34 | INFO     | metabolic_features.py:88 | transform() | Features métaboliques avancées générées. | {}
# 2026-01-03 18:01:34 | INFO     | behavioral_features.py:30 | transform() | Création des features comportementales avancées... | {}
# 2026-01-03 18:01:34 | INFO     | behavioral_features.py:68 | transform() | Features comportementales avancées générées. | {}
# 2026-01-03 18:01:34 | INFO     | lifestyle_features.py:50 | transform() | Application des transformations lifestyle... | {}
# 2026-01-03 18:01:35 | INFO     | lifestyle_features.py:53 | transform() | Transformations lifestyle complétées. | {}
# 2026-01-03 18:01:35 | INFO     | pipeline_feature_engineering.py:120 | transform() | Pipeline exécuté avec succès. Nombre total de colonnes : 52 | {}
# 2026-01-03 18:01:35 | INFO     | 1594397751.py:65 | <module>() | Feature engineering terminé | colonnes_avant=31 | colonnes_après=52 | {}
# 2026-01-03 18:01:35 | DEBUG    | sklearn_splitter.py:37 | __init__() | SklearnDatasetSplitter initialized | {}
# 2026-01-03 18:01:35 | INFO     | sklearn_splitter.py:42 | split() | Starting dataset split | {}
# 2026-01-03 18:01:35 | INFO     | sklearn_splitter.py:57 | split() | Split done | train=(70296, 52) | test=(12406, 52) | {}
# 2026-01-03 18:01:35 | INFO     | 1594397751.py:83 | <module>() | Train shape : (70296, 52) | {}
# 2026-01-03 18:01:35 | INFO     | 1594397751.py:84 | <module>() | Valid shape : (12406, 52) | {}
# 2026-01-03 18:01:35 | INFO     | 1594397751.py:89 | <module>() | Feature selection | 5 features retenues | {}
# 2026-01-03 18:01:35 | INFO     | 1594397751.py:98 | <module>() | Feature selection appliquée | {}
# 2026-01-03 18:01:35 | INFO     | 1594397751.py:109 | <module>() | Dimensions finales | X_train=(70296, 5) | X_valid=(12406, 5) | {}
# 2026-01-03 18:01:35 | INFO     | catboost_trainer.py:38 | __init__() | CatBoostTrainer initialisé avec les paramètres fournis. | {}
# 2026-01-03 18:01:35 | INFO     | catboost_trainer.py:111 | train() | Entraînement CatBoost | train_shape=(70296, 5) | valid_shape=(12406, 5) | {}
# 2026-01-03 18:01:35 | INFO     | catboost_trainer.py:127 | train() | Détection automatique des variables catégorielles : ['glucose_status'] | {}
# 2026-01-03 18:01:35 | INFO     | catboost_trainer.py:137 | train() | Démarrage de l'entraînement CatBoost. | {}
# 0:	learn: 0.2499155	test: 0.2518922	best: 0.2518922 (0)	total: 85.9ms	remaining: 42.9s
# 100:	learn: 0.1988921	test: 0.2212484	best: 0.2161532 (24)	total: 2.58s	remaining: 10.2s
# 200:	learn: 0.1879936	test: 0.2268672	best: 0.2161532 (24)	total: 4.95s	remaining: 7.37s
# 300:	learn: 0.1787925	test: 0.2317398	best: 0.2161532 (24)	total: 6.98s	remaining: 4.62s
# 400:	learn: 0.1716001	test: 0.2348091	best: 0.2161532 (24)	total: 9s	remaining: 2.22s
# 499:	learn: 0.1653170	test: 0.2380953	best: 0.2161532 (24)	total: 10.9s	remaining: 0us
#
# bestTest = 0.2161532394
# bestIteration = 24
#
# Shrink model to first 25 iterations.
# 2026-01-03 18:01:46 | INFO     | catboost_trainer.py:154 | train() | Entraînement CatBoost terminé. | {}
# 2026-01-03 18:01:46 | INFO     | 1594397751.py:139 | <module>() | Entraînement CatBoost terminé | {}
# 2026-01-03 18:01:46 | INFO     | 1594397751.py:152 | <module>() | Modèle sauvegardé : /Users/surelmanda/Downloads/ml-projects/Clean-Architecture-MLops/health_lifestyle_diabetes/models/catboost_diabetes_classifier.cbm | {}
# 2026-01-03 18:01:46 | INFO     | 1594397751.py:160 | <module>() | Modèle rechargé avec succès | {}

# %% [markdown]
# ### 📥 Test Data Ingestion – CSV → DataFrame

# %%
from pathlib import Path
from health_lifestyle_diabetes.infrastructure.logger.config import configure_logging
from health_lifestyle_diabetes.infrastructure.logger.loguru_logger import LoguruLogger
from health_lifestyle_diabetes.infrastructure.utils.config_loader import YamlConfigLoader
from health_lifestyle_diabetes.infrastructure.utils.paths import get_repository_root
from health_lifestyle_diabetes.infrastructure.data_sources.csv_dataset_repository import (
    CSVDatasetRepository
)
from health_lifestyle_diabetes.application.use_cases.load_dataset_use_case import (
    LoadDatasetUseCase
)

# ============================================================
# Configuration
# ============================================================
configure_logging(env="dev")
logger = LoguruLogger()

root_path = get_repository_root()
config_loader = YamlConfigLoader()

# ============================================================
# Paths
# ============================================================
paths_cfg = config_loader.load_config(root_path / "configs/paths.yaml")
test_data_path = root_path / Path(paths_cfg["data"]["input"]["test_dataset"])

# ============================================================
# Dataset loading
# ============================================================
dataset_repo = CSVDatasetRepository(
    source_path=test_data_path,
    logger=logger,
)

load_test_data = LoadDatasetUseCase(
    repository=dataset_repo,
    logger=logger,
)

test_df = load_test_data.execute()

# ============================================================
# Sanity check
# ============================================================
display(test_df.head())
logger.info(
    f"Dataset de test chargé | "
    f"lignes={test_df.shape[0]} | "
    f"colonnes={test_df.shape[1]}"
)
# Out:
# 2026-01-03 18:01:48 | INFO     | config.py:67 | configure_logging() | Loguru configuré avec succès (mode: dev) | {'env': 'dev'}
# 2026-01-03 18:01:48 | INFO     | load_dataset_use_case.py:18 | execute() | Démarrage du chargement du dataset... | {}
# 2026-01-03 18:01:48 | INFO     | csv_dataset_repository.py:54 | load_dataset() | Chargement du dataset depuis : /Users/surelmanda/Downloads/ml-projects/Clean-Architecture-MLops/health_lifestyle_diabetes/data/input/test.csv | {}
# 2026-01-03 18:01:48 | INFO     | csv_dataset_repository.py:61 | load_dataset() | Dataset chargé avec succès (14595 lignes, 31 colonnes). | {}
# 2026-01-03 18:01:48 | INFO     | load_dataset_use_case.py:20 | execute() | Dataset chargé : 14595 lignes, 31 colonnes. | {}
#    Age  gender ethnicity education_level  income_level employment_status  \
# 0   61  Female     White    Postgraduate        Middle           Retired
# 1   44    Male     Asian    Postgraduate  Lower-Middle        Unemployed
# 2   66  Female     White    Postgraduate  Lower-Middle          Employed
# 3   44    Male     Black      Highschool        Middle           Retired
# 4   64    Male     White        Graduate  Upper-Middle          Employed
#
#   smoking_status  alcohol_consumption_per_week  \
# 0          Never                             2
# 1          Never                             0
# 2          Never                             0
# 3          Never                             2
# 4        Current                             2
#
#    physical_activity_minutes_per_week  diet_score  ...  hdl_cholesterol  \
# 0                                 104         6.2  ...               52
# 1                                  91         5.0  ...               52
# 2                                 136         6.6  ...               54
# 3                                 193         4.3  ...               52
# 4                                  95         6.5  ...               59
#
#    ldl_cholesterol  triglycerides  glucose_fasting  glucose_postprandial  \
# 0               50            229              131                   210
# 1              134            136              114                   194
# 2              144            125              118                   194
# 3              138             48               97                   184
# 4              141            179               92                   138
#
#    insulin_level  hba1c  diabetes_risk_score  diabetes_stage  \
# 0           6.09   8.14                 34.0          Type 2
# 1           6.29   7.20                 25.8          Type 2
# 2          15.55   7.36                 46.3          Type 2
# 3           9.27   6.62                 23.4          Type 2
# 4          14.97   5.62                 34.4     No Diabetes
#
#    diagnosed_diabetes
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   0
#
# [5 rows x 31 columns]
# 2026-01-03 18:01:49 | INFO     | 355808870.py:47 | <module>() | Dataset de test chargé | lignes=14595 | colonnes=31 | {}

# %%
from pandas import DataFrame
from catboost import CatBoostClassifier

from health_lifestyle_diabetes.infrastructure.utils.paths import get_repository_root
from health_lifestyle_diabetes.infrastructure.streaming.pandas_dataframe_streamer import (
    PandasDataFrameStreamer
)
from health_lifestyle_diabetes.application.services.dataframe_streamer_service import (
    DataFrameStreamerService
)
from health_lifestyle_diabetes.application.use_cases.apply_feature_engineering_uc import (
    ApplyFeatureEngineeringUseCase
)
from health_lifestyle_diabetes.infrastructure.feature_engineering.pipeline_feature_engineering import (
    FeatureEngineeringPipeline
)
from health_lifestyle_diabetes.infrastructure.logger.loguru_logger import LoguruLogger
from health_lifestyle_diabetes.infrastructure.features_selections import (
    features_selection as fs
)

# ============================================================
# Initialisation des dépendances
# ============================================================
logger = LoguruLogger()

fe_pipeline = FeatureEngineeringPipeline(logger=logger)
apply_feature_engineering = ApplyFeatureEngineeringUseCase(
    pipeline=fe_pipeline,
    logger=logger,
)

streamer = PandasDataFrameStreamer()
streaming_service = DataFrameStreamerService(streamer)

# ============================================================
# Modèle & configuration
# ============================================================
TARGET_COLUMN = fs.ID_COLUMN

root_path = get_repository_root()
model_path = (
    root_path
    / "models"
    / "catboost_diabetes_classifier.cbm"
)

model = CatBoostClassifier()
model.load_model(model_path)

logger.info("Modèle CatBoost chargé pour l'inférence")

logger.info(
    f"Feature selection active | "
    f"{len(fs.SELECTED_FEATURES)} variables utilisées"
)

# ============================================================
# Streaming & inference
# ============================================================
event_index = 0

for record in streaming_service.run(test_df, min_delay=1, max_delay=3):
    logger.info(f"Traitement du record #{event_index}")

    # --------------------------------------------------------
    # 1. Record → DataFrame unitaire
    # --------------------------------------------------------
    record_df = DataFrame([record])

    # --------------------------------------------------------
    # 2. Feature engineering
    # --------------------------------------------------------
    enriched_df = apply_feature_engineering.execute(record_df)

    # --------------------------------------------------------
    # 3. Sélection des features pour l'inférence
    # --------------------------------------------------------
    model_input = enriched_df[fs.SELECTED_FEATURES]

    # --------------------------------------------------------
    # 4. Prédiction
    # --------------------------------------------------------
    prediction_proba = model.predict_proba(model_input)[0, 1]
    prediction_label = int(prediction_proba >= 0.5)

    # --------------------------------------------------------
    # 5. Payload de sortie (JSON métier)
    # --------------------------------------------------------
    prediction_event = {
        "user_id": record.get("user_id"),
        "true_diagnosed_diabetes": record.get("diagnosed_diabetes"),
        "predicted_diagnosed_diabetes": prediction_label,
        "prediction_probability": round(float(prediction_proba), 4),
    }

    # point d'intégration API / Kafka / Event Bus
    print(prediction_event)

    event_index += 1
    if event_index >= 10:  # garde-fou notebook
        break

logger.info("Fin du streaming des données")
# Out:
# 2026-01-03 18:03:16 | INFO     | 1920831522.py:51 | <module>() | Modèle CatBoost chargé pour l'inférence | {}
# 2026-01-03 18:03:16 | INFO     | 1920831522.py:53 | <module>() | Feature selection active | 5 variables utilisées | {}
# 2026-01-03 18:03:16 | INFO     | pandas_dataframe_streamer.py:35 | stream() | Envoi ligne user_id=0eac564c-b395-4e06-add0-ed07af75c9ca | {}
# 2026-01-03 18:03:18 | INFO     | 1920831522.py:64 | <module>() | Traitement du record #0 | {}
# 2026-01-03 18:03:18 | INFO     | apply_feature_engineering_uc.py:39 | execute() | Début du feature engineering | lignes=1 | colonnes_initiales=32 | {}
# {'user_id': '0eac564c-b395-4e06-add0-ed07af75c9ca', 'true_diagnosed_diabetes': 1, 'predicted_diagnosed_diabetes': 1, 'prediction_probability': 1.0}
# 2026-01-03 18:03:18 | INFO     | pipeline_feature_engineering.py:82 | transform() | Démarrage du pipeline complet de Feature Engineering... | {}
# 2026-01-03 18:03:18 | INFO     | exclusion.py:36 | drop_leakage_columns() | Vérification des colonnes à risque de data leakage... | {}
# 2026-01-03 18:03:18 | INFO     | exclusion.py:40 | drop_leakage_columns() | Suppression des colonnes à risque de leakage : ['diabetes_risk_score', 'diabetes_stage'] | {}
# 2026-01-03 18:03:18 | INFO     | base_preprocessing.py:25 | clean_categorical_variables() | Nettoyage des variables catégorielles... | {}
# 2026-01-03 18:03:18 | INFO     | base_preprocessing.py:32 | clean_categorical_variables() | Libellés uniformisés avec succès. | {}
# 2026-01-03 18:03:18 | INFO     | demographics_features.py:82 | transform() | Création des variables démographiques... | {}
# 2026-01-03 18:03:18 | INFO     | demographics_features.py:68 | _create_age_group() | Utilisation du découpage d'âge en 3 catégories. | {}
# 2026-01-03 18:03:18 | INFO     | demographics_features.py:111 | transform() | Variables démographiques complétées. | {}
# 2026-01-03 18:03:18 | INFO     | medical_features.py:86 | transform() | Application des transformations médicales... | {}
# 2026-01-03 18:03:18 | INFO     | medical_features.py:94 | transform() | Transformations médicales complétées. | {}
# 2026-01-03 18:03:18 | INFO     | clinical_features.py:32 | transform() | Calcul des ratios et interactions cliniques... | {}
# 2026-01-03 18:03:18 | INFO     | clinical_features.py:41 | transform() | Variables cliniques ajoutées avec succès. | {}
# 2026-01-03 18:03:18 | INFO     | metabolic_features.py:41 | transform() | Création des features métaboliques avancées... | {}
# 2026-01-03 18:03:18 | INFO     | metabolic_features.py:88 | transform() | Features métaboliques avancées générées. | {}
# 2026-01-03 18:03:18 | INFO     | behavioral_features.py:30 | transform() | Création des features comportementales avancées... | {}
# 2026-01-03 18:03:18 | INFO     | behavioral_features.py:68 | transform() | Features comportementales avancées générées. | {}
# 2026-01-03 18:03:18 | INFO     | lifestyle_features.py:50 | transform() | Application des transformations lifestyle... | {}
# 2026-01-03 18:03:18 | INFO     | lifestyle_features.py:53 | transform() | Transformations lifestyle complétées. | {}
# 2026-01-03 18:03:18 | INFO     | pipeline_feature_engineering.py:120 | transform() | Pipeline exécuté avec succès. Nombre total de colonnes : 53 | {}
# 2026-01-03 18:03:18 | INFO     | apply_feature_engineering_uc.py:47 | execute() | Feature engineering terminé | lignes=1 | colonnes_finales=53 | delta_colonnes=21 | {}
# 2026-01-03 18:03:18 | INFO     | pandas_dataframe_streamer.py:35 | stream() | Envoi ligne user_id=30a015f3-2c97-4e03-9a3a-7a4d2a4ff09b | {}
# 2026-01-03 18:03:19 | INFO     | 1920831522.py:64 | <module>() | Traitement du record #1 | {}
# 2026-01-03 18:03:19 | INFO     | apply_feature_engineering_uc.py:39 | execute() | Début du feature engineering | lignes=1 | colonnes_initiales=32 | {}
# {'user_id': '30a015f3-2c97-4e03-9a3a-7a4d2a4ff09b', 'true_diagnosed_diabetes': 1, 'predicted_diagnosed_diabetes': 1, 'prediction_probability': 1.0}
# 2026-01-03 18:03:19 | INFO     | pipeline_feature_engineering.py:82 | transform() | Démarrage du pipeline complet de Feature Engineering... | {}
# 2026-01-03 18:03:19 | INFO     | exclusion.py:36 | drop_leakage_columns() | Vérification des colonnes à risque de data leakage... | {}
# 2026-01-03 18:03:19 | INFO     | exclusion.py:40 | drop_leakage_columns() | Suppression des colonnes à risque de leakage : ['diabetes_risk_score', 'diabetes_stage'] | {}
# 2026-01-03 18:03:19 | INFO     | base_preprocessing.py:25 | clean_categorical_variables() | Nettoyage des variables catégorielles... | {}
# 2026-01-03 18:03:19 | INFO     | base_preprocessing.py:32 | clean_categorical_variables() | Libellés uniformisés avec succès. | {}
# 2026-01-03 18:03:19 | INFO     | demographics_features.py:82 | transform() | Création des variables démographiques... | {}
# 2026-01-03 18:03:19 | INFO     | demographics_features.py:68 | _create_age_group() | Utilisation du découpage d'âge en 3 catégories. | {}
# 2026-01-03 18:03:19 | INFO     | demographics_features.py:111 | transform() | Variables démographiques complétées. | {}
# 2026-01-03 18:03:19 | INFO     | medical_features.py:86 | transform() | Application des transformations médicales... | {}
# 2026-01-03 18:03:19 | INFO     | medical_features.py:94 | transform() | Transformations médicales complétées. | {}
# 2026-01-03 18:03:19 | INFO     | clinical_features.py:32 | transform() | Calcul des ratios et interactions cliniques... | {}
# 2026-01-03 18:03:19 | INFO     | clinical_features.py:41 | transform() | Variables cliniques ajoutées avec succès. | {}
# 2026-01-03 18:03:19 | INFO     | metabolic_features.py:41 | transform() | Création des features métaboliques avancées... | {}
# 2026-01-03 18:03:19 | INFO     | metabolic_features.py:88 | transform() | Features métaboliques avancées générées. | {}
# 2026-01-03 18:03:19 | INFO     | behavioral_features.py:30 | transform() | Création des features comportementales avancées... | {}
# 2026-01-03 18:03:19 | INFO     | behavioral_features.py:68 | transform() | Features comportementales avancées générées. | {}
# 2026-01-03 18:03:19 | INFO     | lifestyle_features.py:50 | transform() | Application des transformations lifestyle... | {}
# 2026-01-03 18:03:19 | INFO     | lifestyle_features.py:53 | transform() | Transformations lifestyle complétées. | {}
# 2026-01-03 18:03:19 | INFO     | pipeline_feature_engineering.py:120 | transform() | Pipeline exécuté avec succès. Nombre total de colonnes : 53 | {}
# 2026-01-03 18:03:19 | INFO     | apply_feature_engineering_uc.py:47 | execute() | Feature engineering terminé | lignes=1 | colonnes_finales=53 | delta_colonnes=21 | {}
# 2026-01-03 18:03:19 | INFO     | pandas_dataframe_streamer.py:35 | stream() | Envoi ligne user_id=b4ef9806-ea82-421d-a9d6-e412b37131d3 | {}
# 2026-01-03 18:03:22 | INFO     | 1920831522.py:64 | <module>() | Traitement du record #2 | {}
# 2026-01-03 18:03:22 | INFO     | apply_feature_engineering_uc.py:39 | execute() | Début du feature engineering | lignes=1 | colonnes_initiales=32 | {}
# {'user_id': 'b4ef9806-ea82-421d-a9d6-e412b37131d3', 'true_diagnosed_diabetes': 1, 'predicted_diagnosed_diabetes': 1, 'prediction_probability': 1.0}
# 2026-01-03 18:03:22 | INFO     | pipeline_feature_engineering.py:82 | transform() | Démarrage du pipeline complet de Feature Engineering... | {}
# 2026-01-03 18:03:22 | INFO     | exclusion.py:36 | drop_leakage_columns() | Vérification des colonnes à risque de data leakage... | {}
# 2026-01-03 18:03:22 | INFO     | exclusion.py:40 | drop_leakage_columns() | Suppression des colonnes à risque de leakage : ['diabetes_risk_score', 'diabetes_stage'] | {}
# 2026-01-03 18:03:22 | INFO     | base_preprocessing.py:25 | clean_categorical_variables() | Nettoyage des variables catégorielles... | {}
# 2026-01-03 18:03:22 | INFO     | base_preprocessing.py:32 | clean_categorical_variables() | Libellés uniformisés avec succès. | {}
# 2026-01-03 18:03:22 | INFO     | demographics_features.py:82 | transform() | Création des variables démographiques... | {}
# 2026-01-03 18:03:22 | INFO     | demographics_features.py:68 | _create_age_group() | Utilisation du découpage d'âge en 3 catégories. | {}
# 2026-01-03 18:03:22 | INFO     | demographics_features.py:111 | transform() | Variables démographiques complétées. | {}
# 2026-01-03 18:03:22 | INFO     | medical_features.py:86 | transform() | Application des transformations médicales... | {}
# 2026-01-03 18:03:22 | INFO     | medical_features.py:94 | transform() | Transformations médicales complétées. | {}
# 2026-01-03 18:03:22 | INFO     | clinical_features.py:32 | transform() | Calcul des ratios et interactions cliniques... | {}
# 2026-01-03 18:03:22 | INFO     | clinical_features.py:41 | transform() | Variables cliniques ajoutées avec succès. | {}
# 2026-01-03 18:03:22 | INFO     | metabolic_features.py:41 | transform() | Création des features métaboliques avancées... | {}
# 2026-01-03 18:03:22 | INFO     | metabolic_features.py:88 | transform() | Features métaboliques avancées générées. | {}
# 2026-01-03 18:03:22 | INFO     | behavioral_features.py:30 | transform() | Création des features comportementales avancées... | {}
# 2026-01-03 18:03:22 | INFO     | behavioral_features.py:68 | transform() | Features comportementales avancées générées. | {}
# 2026-01-03 18:03:22 | INFO     | lifestyle_features.py:50 | transform() | Application des transformations lifestyle... | {}
# 2026-01-03 18:03:22 | INFO     | lifestyle_features.py:53 | transform() | Transformations lifestyle complétées. | {}
# 2026-01-03 18:03:22 | INFO     | pipeline_feature_engineering.py:120 | transform() | Pipeline exécuté avec succès. Nombre total de colonnes : 53 | {}
# 2026-01-03 18:03:22 | INFO     | apply_feature_engineering_uc.py:47 | execute() | Feature engineering terminé | lignes=1 | colonnes_finales=53 | delta_colonnes=21 | {}
# 2026-01-03 18:03:22 | INFO     | pandas_dataframe_streamer.py:35 | stream() | Envoi ligne user_id=c711cb8e-d011-4040-921c-bdf4d36ea6a2 | {}
# 2026-01-03 18:03:24 | INFO     | 1920831522.py:64 | <module>() | Traitement du record #3 | {}
# 2026-01-03 18:03:24 | INFO     | apply_feature_engineering_uc.py:39 | execute() | Début du feature engineering | lignes=1 | colonnes_initiales=32 | {}
# 2026-01-03 18:03:24 | INFO     | pipeline_feature_engineering.py:82 | transform() | Démarrage du pipeline complet de Feature Engineering... | {}
# {'user_id': 'c711cb8e-d011-4040-921c-bdf4d36ea6a2', 'true_diagnosed_diabetes': 1, 'predicted_diagnosed_diabetes': 1, 'prediction_probability': 0.9999}
# 2026-01-03 18:03:24 | INFO     | exclusion.py:36 | drop_leakage_columns() | Vérification des colonnes à risque de data leakage... | {}
# 2026-01-03 18:03:24 | INFO     | exclusion.py:40 | drop_leakage_columns() | Suppression des colonnes à risque de leakage : ['diabetes_risk_score', 'diabetes_stage'] | {}
# 2026-01-03 18:03:24 | INFO     | base_preprocessing.py:25 | clean_categorical_variables() | Nettoyage des variables catégorielles... | {}
# 2026-01-03 18:03:24 | INFO     | base_preprocessing.py:32 | clean_categorical_variables() | Libellés uniformisés avec succès. | {}
# 2026-01-03 18:03:24 | INFO     | demographics_features.py:82 | transform() | Création des variables démographiques... | {}
# 2026-01-03 18:03:24 | INFO     | demographics_features.py:68 | _create_age_group() | Utilisation du découpage d'âge en 3 catégories. | {}
# 2026-01-03 18:03:24 | INFO     | demographics_features.py:111 | transform() | Variables démographiques complétées. | {}
# 2026-01-03 18:03:24 | INFO     | medical_features.py:86 | transform() | Application des transformations médicales... | {}
# 2026-01-03 18:03:24 | INFO     | medical_features.py:94 | transform() | Transformations médicales complétées. | {}
# 2026-01-03 18:03:24 | INFO     | clinical_features.py:32 | transform() | Calcul des ratios et interactions cliniques... | {}
# 2026-01-03 18:03:24 | INFO     | clinical_features.py:41 | transform() | Variables cliniques ajoutées avec succès. | {}
# 2026-01-03 18:03:24 | INFO     | metabolic_features.py:41 | transform() | Création des features métaboliques avancées... | {}
# 2026-01-03 18:03:24 | INFO     | metabolic_features.py:88 | transform() | Features métaboliques avancées générées. | {}
# 2026-01-03 18:03:24 | INFO     | behavioral_features.py:30 | transform() | Création des features comportementales avancées... | {}
# 2026-01-03 18:03:24 | INFO     | behavioral_features.py:68 | transform() | Features comportementales avancées générées. | {}
# 2026-01-03 18:03:24 | INFO     | lifestyle_features.py:50 | transform() | Application des transformations lifestyle... | {}
# 2026-01-03 18:03:24 | INFO     | lifestyle_features.py:53 | transform() | Transformations lifestyle complétées. | {}
# 2026-01-03 18:03:24 | INFO     | pipeline_feature_engineering.py:120 | transform() | Pipeline exécuté avec succès. Nombre total de colonnes : 53 | {}
# 2026-01-03 18:03:24 | INFO     | apply_feature_engineering_uc.py:47 | execute() | Feature engineering terminé | lignes=1 | colonnes_finales=53 | delta_colonnes=21 | {}
# 2026-01-03 18:03:24 | INFO     | pandas_dataframe_streamer.py:35 | stream() | Envoi ligne user_id=132dbc81-06ec-44a5-8a9e-d31048c50390 | {}
# 2026-01-03 18:03:27 | INFO     | 1920831522.py:64 | <module>() | Traitement du record #4 | {}
# 2026-01-03 18:03:27 | INFO     | apply_feature_engineering_uc.py:39 | execute() | Début du feature engineering | lignes=1 | colonnes_initiales=32 | {}
# {'user_id': '132dbc81-06ec-44a5-8a9e-d31048c50390', 'true_diagnosed_diabetes': 0, 'predicted_diagnosed_diabetes': 0, 'prediction_probability': 0.181}
# 2026-01-03 18:03:27 | INFO     | pipeline_feature_engineering.py:82 | transform() | Démarrage du pipeline complet de Feature Engineering... | {}
# 2026-01-03 18:03:27 | INFO     | exclusion.py:36 | drop_leakage_columns() | Vérification des colonnes à risque de data leakage... | {}
# 2026-01-03 18:03:27 | INFO     | exclusion.py:40 | drop_leakage_columns() | Suppression des colonnes à risque de leakage : ['diabetes_risk_score', 'diabetes_stage'] | {}
# 2026-01-03 18:03:27 | INFO     | base_preprocessing.py:25 | clean_categorical_variables() | Nettoyage des variables catégorielles... | {}
# 2026-01-03 18:03:27 | INFO     | base_preprocessing.py:32 | clean_categorical_variables() | Libellés uniformisés avec succès. | {}
# 2026-01-03 18:03:27 | INFO     | demographics_features.py:82 | transform() | Création des variables démographiques... | {}
# 2026-01-03 18:03:27 | INFO     | demographics_features.py:68 | _create_age_group() | Utilisation du découpage d'âge en 3 catégories. | {}
# 2026-01-03 18:03:27 | INFO     | demographics_features.py:111 | transform() | Variables démographiques complétées. | {}
# 2026-01-03 18:03:27 | INFO     | medical_features.py:86 | transform() | Application des transformations médicales... | {}
# 2026-01-03 18:03:27 | INFO     | medical_features.py:94 | transform() | Transformations médicales complétées. | {}
# 2026-01-03 18:03:27 | INFO     | clinical_features.py:32 | transform() | Calcul des ratios et interactions cliniques... | {}
# 2026-01-03 18:03:27 | INFO     | clinical_features.py:41 | transform() | Variables cliniques ajoutées avec succès. | {}
# 2026-01-03 18:03:27 | INFO     | metabolic_features.py:41 | transform() | Création des features métaboliques avancées... | {}
# 2026-01-03 18:03:27 | INFO     | metabolic_features.py:88 | transform() | Features métaboliques avancées générées. | {}
# 2026-01-03 18:03:27 | INFO     | behavioral_features.py:30 | transform() | Création des features comportementales avancées... | {}
# 2026-01-03 18:03:27 | INFO     | behavioral_features.py:68 | transform() | Features comportementales avancées générées. | {}
# 2026-01-03 18:03:27 | INFO     | lifestyle_features.py:50 | transform() | Application des transformations lifestyle... | {}
# 2026-01-03 18:03:27 | INFO     | lifestyle_features.py:53 | transform() | Transformations lifestyle complétées. | {}
# 2026-01-03 18:03:27 | INFO     | pipeline_feature_engineering.py:120 | transform() | Pipeline exécuté avec succès. Nombre total de colonnes : 53 | {}
# 2026-01-03 18:03:27 | INFO     | apply_feature_engineering_uc.py:47 | execute() | Feature engineering terminé | lignes=1 | colonnes_finales=53 | delta_colonnes=21 | {}
# 2026-01-03 18:03:27 | INFO     | pandas_dataframe_streamer.py:35 | stream() | Envoi ligne user_id=9c62a127-446d-473b-a99c-0604f67ff1de | {}
# 2026-01-03 18:03:29 | INFO     | 1920831522.py:64 | <module>() | Traitement du record #5 | {}
# 2026-01-03 18:03:29 | INFO     | apply_feature_engineering_uc.py:39 | execute() | Début du feature engineering | lignes=1 | colonnes_initiales=32 | {}
# 2026-01-03 18:03:29 | INFO     | pipeline_feature_engineering.py:82 | transform() | Démarrage du pipeline complet de Feature Engineering... | {}
# 2026-01-03 18:03:29 | INFO     | exclusion.py:36 | drop_leakage_columns() | Vérification des colonnes à risque de data leakage... | {}
# {'user_id': '9c62a127-446d-473b-a99c-0604f67ff1de', 'true_diagnosed_diabetes': 0, 'predicted_diagnosed_diabetes': 0, 'prediction_probability': 0.1802}
# 2026-01-03 18:03:29 | INFO     | exclusion.py:40 | drop_leakage_columns() | Suppression des colonnes à risque de leakage : ['diabetes_risk_score', 'diabetes_stage'] | {}
# 2026-01-03 18:03:29 | INFO     | base_preprocessing.py:25 | clean_categorical_variables() | Nettoyage des variables catégorielles... | {}
# 2026-01-03 18:03:29 | INFO     | base_preprocessing.py:32 | clean_categorical_variables() | Libellés uniformisés avec succès. | {}
# 2026-01-03 18:03:29 | INFO     | demographics_features.py:82 | transform() | Création des variables démographiques... | {}
# 2026-01-03 18:03:29 | INFO     | demographics_features.py:68 | _create_age_group() | Utilisation du découpage d'âge en 3 catégories. | {}
# 2026-01-03 18:03:29 | INFO     | demographics_features.py:111 | transform() | Variables démographiques complétées. | {}
# 2026-01-03 18:03:29 | INFO     | medical_features.py:86 | transform() | Application des transformations médicales... | {}
# 2026-01-03 18:03:29 | INFO     | medical_features.py:94 | transform() | Transformations médicales complétées. | {}
# 2026-01-03 18:03:29 | INFO     | clinical_features.py:32 | transform() | Calcul des ratios et interactions cliniques... | {}
# 2026-01-03 18:03:29 | INFO     | clinical_features.py:41 | transform() | Variables cliniques ajoutées avec succès. | {}
# 2026-01-03 18:03:29 | INFO     | metabolic_features.py:41 | transform() | Création des features métaboliques avancées... | {}
# 2026-01-03 18:03:29 | INFO     | metabolic_features.py:88 | transform() | Features métaboliques avancées générées. | {}
# 2026-01-03 18:03:29 | INFO     | behavioral_features.py:30 | transform() | Création des features comportementales avancées... | {}
# 2026-01-03 18:03:29 | INFO     | behavioral_features.py:68 | transform() | Features comportementales avancées générées. | {}
# 2026-01-03 18:03:29 | INFO     | lifestyle_features.py:50 | transform() | Application des transformations lifestyle... | {}
# 2026-01-03 18:03:29 | INFO     | lifestyle_features.py:53 | transform() | Transformations lifestyle complétées. | {}
# 2026-01-03 18:03:29 | INFO     | pipeline_feature_engineering.py:120 | transform() | Pipeline exécuté avec succès. Nombre total de colonnes : 53 | {}
# 2026-01-03 18:03:29 | INFO     | apply_feature_engineering_uc.py:47 | execute() | Feature engineering terminé | lignes=1 | colonnes_finales=53 | delta_colonnes=21 | {}
# 2026-01-03 18:03:29 | INFO     | pandas_dataframe_streamer.py:35 | stream() | Envoi ligne user_id=14b17601-7686-48bc-927c-7f29e126922e | {}
# 2026-01-03 18:03:31 | INFO     | 1920831522.py:64 | <module>() | Traitement du record #6 | {}
# 2026-01-03 18:03:31 | INFO     | apply_feature_engineering_uc.py:39 | execute() | Début du feature engineering | lignes=1 | colonnes_initiales=32 | {}
# 2026-01-03 18:03:31 | INFO     | pipeline_feature_engineering.py:82 | transform() | Démarrage du pipeline complet de Feature Engineering... | {}
# 2026-01-03 18:03:31 | INFO     | exclusion.py:36 | drop_leakage_columns() | Vérification des colonnes à risque de data leakage... | {}
# {'user_id': '14b17601-7686-48bc-927c-7f29e126922e', 'true_diagnosed_diabetes': 0, 'predicted_diagnosed_diabetes': 0, 'prediction_probability': 0.0813}
# 2026-01-03 18:03:31 | INFO     | exclusion.py:40 | drop_leakage_columns() | Suppression des colonnes à risque de leakage : ['diabetes_risk_score', 'diabetes_stage'] | {}
# 2026-01-03 18:03:31 | INFO     | base_preprocessing.py:25 | clean_categorical_variables() | Nettoyage des variables catégorielles... | {}
# 2026-01-03 18:03:31 | INFO     | base_preprocessing.py:32 | clean_categorical_variables() | Libellés uniformisés avec succès. | {}
# 2026-01-03 18:03:31 | INFO     | demographics_features.py:82 | transform() | Création des variables démographiques... | {}
# 2026-01-03 18:03:31 | INFO     | demographics_features.py:68 | _create_age_group() | Utilisation du découpage d'âge en 3 catégories. | {}
# 2026-01-03 18:03:31 | INFO     | demographics_features.py:111 | transform() | Variables démographiques complétées. | {}
# 2026-01-03 18:03:31 | INFO     | medical_features.py:86 | transform() | Application des transformations médicales... | {}
# 2026-01-03 18:03:31 | INFO     | medical_features.py:94 | transform() | Transformations médicales complétées. | {}
# 2026-01-03 18:03:31 | INFO     | clinical_features.py:32 | transform() | Calcul des ratios et interactions cliniques... | {}
# 2026-01-03 18:03:31 | INFO     | clinical_features.py:41 | transform() | Variables cliniques ajoutées avec succès. | {}
# 2026-01-03 18:03:31 | INFO     | metabolic_features.py:41 | transform() | Création des features métaboliques avancées... | {}
# 2026-01-03 18:03:31 | INFO     | metabolic_features.py:88 | transform() | Features métaboliques avancées générées. | {}
# 2026-01-03 18:03:31 | INFO     | behavioral_features.py:30 | transform() | Création des features comportementales avancées... | {}
# 2026-01-03 18:03:31 | INFO     | behavioral_features.py:68 | transform() | Features comportementales avancées générées. | {}
# 2026-01-03 18:03:31 | INFO     | lifestyle_features.py:50 | transform() | Application des transformations lifestyle... | {}
# 2026-01-03 18:03:31 | INFO     | lifestyle_features.py:53 | transform() | Transformations lifestyle complétées. | {}
# 2026-01-03 18:03:31 | INFO     | pipeline_feature_engineering.py:120 | transform() | Pipeline exécuté avec succès. Nombre total de colonnes : 53 | {}
# 2026-01-03 18:03:31 | INFO     | apply_feature_engineering_uc.py:47 | execute() | Feature engineering terminé | lignes=1 | colonnes_finales=53 | delta_colonnes=21 | {}
# 2026-01-03 18:03:31 | INFO     | pandas_dataframe_streamer.py:35 | stream() | Envoi ligne user_id=fedeb570-28d1-4734-ae3f-784f852cdf3a | {}
# 2026-01-03 18:03:34 | INFO     | 1920831522.py:64 | <module>() | Traitement du record #7 | {}
# 2026-01-03 18:03:34 | INFO     | apply_feature_engineering_uc.py:39 | execute() | Début du feature engineering | lignes=1 | colonnes_initiales=32 | {}
# {'user_id': 'fedeb570-28d1-4734-ae3f-784f852cdf3a', 'true_diagnosed_diabetes': 1, 'predicted_diagnosed_diabetes': 1, 'prediction_probability': 0.9999}
# 2026-01-03 18:03:34 | INFO     | pipeline_feature_engineering.py:82 | transform() | Démarrage du pipeline complet de Feature Engineering... | {}
# 2026-01-03 18:03:34 | INFO     | exclusion.py:36 | drop_leakage_columns() | Vérification des colonnes à risque de data leakage... | {}
# 2026-01-03 18:03:34 | INFO     | exclusion.py:40 | drop_leakage_columns() | Suppression des colonnes à risque de leakage : ['diabetes_risk_score', 'diabetes_stage'] | {}
# 2026-01-03 18:03:34 | INFO     | base_preprocessing.py:25 | clean_categorical_variables() | Nettoyage des variables catégorielles... | {}
# 2026-01-03 18:03:34 | INFO     | base_preprocessing.py:32 | clean_categorical_variables() | Libellés uniformisés avec succès. | {}
# 2026-01-03 18:03:34 | INFO     | demographics_features.py:82 | transform() | Création des variables démographiques... | {}
# 2026-01-03 18:03:34 | INFO     | demographics_features.py:68 | _create_age_group() | Utilisation du découpage d'âge en 3 catégories. | {}
# 2026-01-03 18:03:34 | INFO     | demographics_features.py:111 | transform() | Variables démographiques complétées. | {}
# 2026-01-03 18:03:34 | INFO     | medical_features.py:86 | transform() | Application des transformations médicales... | {}
# 2026-01-03 18:03:34 | INFO     | medical_features.py:94 | transform() | Transformations médicales complétées. | {}
# 2026-01-03 18:03:34 | INFO     | clinical_features.py:32 | transform() | Calcul des ratios et interactions cliniques... | {}
# 2026-01-03 18:03:34 | INFO     | clinical_features.py:41 | transform() | Variables cliniques ajoutées avec succès. | {}
# 2026-01-03 18:03:34 | INFO     | metabolic_features.py:41 | transform() | Création des features métaboliques avancées... | {}
# 2026-01-03 18:03:34 | INFO     | metabolic_features.py:88 | transform() | Features métaboliques avancées générées. | {}
# 2026-01-03 18:03:34 | INFO     | behavioral_features.py:30 | transform() | Création des features comportementales avancées... | {}
# 2026-01-03 18:03:34 | INFO     | behavioral_features.py:68 | transform() | Features comportementales avancées générées. | {}
# 2026-01-03 18:03:34 | INFO     | lifestyle_features.py:50 | transform() | Application des transformations lifestyle... | {}
# 2026-01-03 18:03:34 | INFO     | lifestyle_features.py:53 | transform() | Transformations lifestyle complétées. | {}
# 2026-01-03 18:03:34 | INFO     | pipeline_feature_engineering.py:120 | transform() | Pipeline exécuté avec succès. Nombre total de colonnes : 53 | {}
# 2026-01-03 18:03:34 | INFO     | apply_feature_engineering_uc.py:47 | execute() | Feature engineering terminé | lignes=1 | colonnes_finales=53 | delta_colonnes=21 | {}
# 2026-01-03 18:03:34 | INFO     | pandas_dataframe_streamer.py:35 | stream() | Envoi ligne user_id=c4adc62c-aa58-446c-aacc-1f4718371652 | {}
# 2026-01-03 18:03:36 | INFO     | 1920831522.py:64 | <module>() | Traitement du record #8 | {}
# 2026-01-03 18:03:36 | INFO     | apply_feature_engineering_uc.py:39 | execute() | Début du feature engineering | lignes=1 | colonnes_initiales=32 | {}
# {'user_id': 'c4adc62c-aa58-446c-aacc-1f4718371652', 'true_diagnosed_diabetes': 1, 'predicted_diagnosed_diabetes': 1, 'prediction_probability': 1.0}2026-01-03 18:03:36 | INFO     | pipeline_feature_engineering.py:82 | transform() | Démarrage du pipeline complet de Feature Engineering... | {}
#
# 2026-01-03 18:03:36 | INFO     | exclusion.py:36 | drop_leakage_columns() | Vérification des colonnes à risque de data leakage... | {}
# 2026-01-03 18:03:36 | INFO     | exclusion.py:40 | drop_leakage_columns() | Suppression des colonnes à risque de leakage : ['diabetes_risk_score', 'diabetes_stage'] | {}
# 2026-01-03 18:03:36 | INFO     | base_preprocessing.py:25 | clean_categorical_variables() | Nettoyage des variables catégorielles... | {}
# 2026-01-03 18:03:36 | INFO     | base_preprocessing.py:32 | clean_categorical_variables() | Libellés uniformisés avec succès. | {}
# 2026-01-03 18:03:36 | INFO     | demographics_features.py:82 | transform() | Création des variables démographiques... | {}
# 2026-01-03 18:03:36 | INFO     | demographics_features.py:68 | _create_age_group() | Utilisation du découpage d'âge en 3 catégories. | {}
# 2026-01-03 18:03:36 | INFO     | demographics_features.py:111 | transform() | Variables démographiques complétées. | {}
# 2026-01-03 18:03:36 | INFO     | medical_features.py:86 | transform() | Application des transformations médicales... | {}
# 2026-01-03 18:03:36 | INFO     | medical_features.py:94 | transform() | Transformations médicales complétées. | {}
# 2026-01-03 18:03:36 | INFO     | clinical_features.py:32 | transform() | Calcul des ratios et interactions cliniques... | {}
# 2026-01-03 18:03:36 | INFO     | clinical_features.py:41 | transform() | Variables cliniques ajoutées avec succès. | {}
# 2026-01-03 18:03:36 | INFO     | metabolic_features.py:41 | transform() | Création des features métaboliques avancées... | {}
# 2026-01-03 18:03:36 | INFO     | metabolic_features.py:88 | transform() | Features métaboliques avancées générées. | {}
# 2026-01-03 18:03:36 | INFO     | behavioral_features.py:30 | transform() | Création des features comportementales avancées... | {}
# 2026-01-03 18:03:36 | INFO     | behavioral_features.py:68 | transform() | Features comportementales avancées générées. | {}
# 2026-01-03 18:03:36 | INFO     | lifestyle_features.py:50 | transform() | Application des transformations lifestyle... | {}
# 2026-01-03 18:03:36 | INFO     | lifestyle_features.py:53 | transform() | Transformations lifestyle complétées. | {}
# 2026-01-03 18:03:36 | INFO     | pipeline_feature_engineering.py:120 | transform() | Pipeline exécuté avec succès. Nombre total de colonnes : 53 | {}
# 2026-01-03 18:03:36 | INFO     | apply_feature_engineering_uc.py:47 | execute() | Feature engineering terminé | lignes=1 | colonnes_finales=53 | delta_colonnes=21 | {}
# 2026-01-03 18:03:36 | INFO     | pandas_dataframe_streamer.py:35 | stream() | Envoi ligne user_id=914a6b24-139d-4e64-8c8f-38e46d710134 | {}
# 2026-01-03 18:03:38 | INFO     | 1920831522.py:64 | <module>() | Traitement du record #9 | {}
# 2026-01-03 18:03:38 | INFO     | apply_feature_engineering_uc.py:39 | execute() | Début du feature engineering | lignes=1 | colonnes_initiales=32 | {}
# {'user_id': '914a6b24-139d-4e64-8c8f-38e46d710134', 'true_diagnosed_diabetes': 1, 'predicted_diagnosed_diabetes': 1, 'prediction_probability': 1.0}
# 2026-01-03 18:03:38 | INFO     | pipeline_feature_engineering.py:82 | transform() | Démarrage du pipeline complet de Feature Engineering... | {}
# 2026-01-03 18:03:38 | INFO     | exclusion.py:36 | drop_leakage_columns() | Vérification des colonnes à risque de data leakage... | {}
# 2026-01-03 18:03:38 | INFO     | exclusion.py:40 | drop_leakage_columns() | Suppression des colonnes à risque de leakage : ['diabetes_risk_score', 'diabetes_stage'] | {}
# 2026-01-03 18:03:38 | INFO     | base_preprocessing.py:25 | clean_categorical_variables() | Nettoyage des variables catégorielles... | {}
# 2026-01-03 18:03:38 | INFO     | base_preprocessing.py:32 | clean_categorical_variables() | Libellés uniformisés avec succès. | {}
# 2026-01-03 18:03:38 | INFO     | demographics_features.py:82 | transform() | Création des variables démographiques... | {}
# 2026-01-03 18:03:38 | INFO     | demographics_features.py:68 | _create_age_group() | Utilisation du découpage d'âge en 3 catégories. | {}
# 2026-01-03 18:03:38 | INFO     | demographics_features.py:111 | transform() | Variables démographiques complétées. | {}
# 2026-01-03 18:03:38 | INFO     | medical_features.py:86 | transform() | Application des transformations médicales... | {}
# 2026-01-03 18:03:38 | INFO     | medical_features.py:94 | transform() | Transformations médicales complétées. | {}
# 2026-01-03 18:03:38 | INFO     | clinical_features.py:32 | transform() | Calcul des ratios et interactions cliniques... | {}
# 2026-01-03 18:03:38 | INFO     | clinical_features.py:41 | transform() | Variables cliniques ajoutées avec succès. | {}
# 2026-01-03 18:03:38 | INFO     | metabolic_features.py:41 | transform() | Création des features métaboliques avancées... | {}
# 2026-01-03 18:03:38 | INFO     | metabolic_features.py:88 | transform() | Features métaboliques avancées générées. | {}
# 2026-01-03 18:03:38 | INFO     | behavioral_features.py:30 | transform() | Création des features comportementales avancées... | {}
# 2026-01-03 18:03:38 | INFO     | behavioral_features.py:68 | transform() | Features comportementales avancées générées. | {}
# 2026-01-03 18:03:38 | INFO     | lifestyle_features.py:50 | transform() | Application des transformations lifestyle... | {}
# 2026-01-03 18:03:38 | INFO     | lifestyle_features.py:53 | transform() | Transformations lifestyle complétées. | {}
# 2026-01-03 18:03:38 | INFO     | pipeline_feature_engineering.py:120 | transform() | Pipeline exécuté avec succès. Nombre total de colonnes : 53 | {}
# 2026-01-03 18:03:38 | INFO     | apply_feature_engineering_uc.py:47 | execute() | Feature engineering terminé | lignes=1 | colonnes_finales=53 | delta_colonnes=21 | {}
# 2026-01-03 18:03:38 | INFO     | 1920831522.py:104 | <module>() | Fin du streaming des données | {}
